# %% [markdown]
# 1. *Data Inspection*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
import warnings
warnings.filterwarnings('ignore')

# %%
# Set display option
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# Load the dataset
df_raw = pd.read_csv("../data/raw/sapacr-2008-2023-v1.1.csv", encoding='latin1')
df_raw.head(5)
# Out:
#         year   station                loc_mn                 dc_mn  longitude  \
# 0  2008/2009  yeoville  city of johannesburg  city of johannesburg   28.06281
# 1  2009/2010  yeoville  city of johannesburg  city of johannesburg   28.06281
# 2  2010/2011  yeoville  city of johannesburg  city of johannesburg   28.06281
# 3  2011/2012  yeoville  city of johannesburg  city of johannesburg   28.06281
# 4  2012/2013  yeoville  city of johannesburg  city of johannesburg   28.06281
#
#    latitude  other_theft  arson  assault_gbh  attempted_murder  \
# 0  -26.1829          491      3          570                25
# 1  -26.1829          452      5          625                 9
# 2  -26.1829          525      1          586                15
# 3  -26.1829          559      2          591                18
# 4  -26.1829          562      0          556                29
#
#    attempted_sexoff  bank_robbery  burglary_nonres  burglary_res  carjacking  \
# 0                 3             0              104           226          25
# 1                 3             0               86           180          35
# 2                 5             0               83           231          23
# 3                 5             0               92           199          54
# 4                 5             0               73           210          48
#
#    commercial_crime  common_assault  common_robbery  contact_sexoff  dui  \
# 0               161             443             132               1  213
# 1               154             473             127               2  264
# 2               247             469             113               3  228
# 3               197             437             103               4  340
# 4               129             441             134               5  351
#
#    drug_crime  illegal_firearms  kidnapping  malicious_damage  murder  rape  \
# 0         113                34           1               236      24    58
# 1         283                22           1               252      14    55
# 2         108                10           1               208      21    60
# 3         161                18           1               210      10    42
# 4         155                28           1               262      17    71
#
#    robbery_nonres  robbery_res  cash_transit_robbery  aggr_robbery  \
# 0              34           42                     1           293
# 1              27           57                     1           276
# 2              36           27                     0           238
# 3              54           46                     0           328
# 4              51           56                     1           355
#
#    sexual_assault  sexual_offences  police_detected_sexoff  shoplifting  \
# 0               7              119                       0          218
# 1              13              115                       0          185
# 2              23              101                       0          164
# 3               3               52                       1          111
# 4              17               96                       3          133
#
#    stock_theft  vehicle_theft  theft_from_vehicle  truck_hijacking
# 0            0            143                 272                0
# 1            0            124                 300                0
# 2            0             96                 256                0
# 3            0            104                 243                0
# 4            0            136                 380                0

# %%
print("Dataset loaded, Shape:", df_raw.shape)
# Out:
# Dataset loaded, Shape: (17265, 38)

# %% [markdown]
# 2. *Data Auditing*

# %%
# 1. Basic info
print("===Basic Info===")
df_raw.info()
# Out:
# ===Basic Info===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17265 entries, 0 to 17264
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   year                    17265 non-null  object
#  1   station                 17265 non-null  object
#  2   loc_mn                  16980 non-null  object
#  3   dc_mn                   16980 non-null  object
#  4   longitude               16965 non-null  float64
#  5   latitude                16965 non-null  float64
#  6   other_theft             17265 non-null  int64
#  7   arson                   17265 non-null  int64
#  8   assault_gbh             17265 non-null  int64
#  9   attempted_murder        17265 non-null  int64
#  10  attempted_sexoff        17265 non-null  int64
#  11  bank_robbery            17265 non-null  int64
#  12  burglary_nonres         17265 non-null  int64
#  13  burglary_res            17265 non-null  int64
#  14  carjacking              17265 non-null  int64
#  15  commercial_crime        17265 non-null  int64
#  16  common_assault          17265 non-null  int64
#  17  common_robbery          17265 non-null  int64
#  18  contact_sexoff          17265 non-null  int64
#  19  dui                     17265 non-null  int64
#  20  drug_crime              17265 non-null  int64
#  21  illegal_firearms        17265 non-null  int64
#  22  kidnapping              17265 non-null  int64
#  23  malicious_damage        17265 non-null  int64
#  24  murder                  17265 non-null  int64
#  25  rape                    17265 non-null  int64
#  26  robbery_nonres          17265 non-null  int64
#  27  robbery_res             17265 non-null  int64
#  28  cash_transit_robbery    17265 non-null  int64
#  29  aggr_robbery            17265 non-null  int64
#  30  sexual_assault          17265 non-null  int64
#  31  sexual_offences         17265 non-null  int64
#  32  police_detected_sexoff  17265 non-null  int64
#  33  shoplifting             17265 non-null  int64
#  34  stock_theft             17265 non-null  int64
#  35  vehicle_theft           17265 non-null  int64
#  36  theft_from_vehicle      17265 non-null  int64
#  37  truck_hijacking         17265 non-null  int64
# dtypes: float64(2), int64(32), object(4)
# memory usage: 5.0+ MB

# %%
# 2. Summary stats for numeric columns
print("\n===Summary Stats===")
df_raw.describe(include='all')
# Out:
# ===Summary Stats===
#              year   station             loc_mn              dc_mn  \
# count       17265     17265              16980              16980
# unique         15      1151                210                 52
# top     2008/2009  yeoville  city of cape town  city of cape town
# freq         1151        15                900                900
# mean          NaN       NaN                NaN                NaN
# std           NaN       NaN                NaN                NaN
# min           NaN       NaN                NaN                NaN
# 25%           NaN       NaN                NaN                NaN
# 50%           NaN       NaN                NaN                NaN
# 75%           NaN       NaN                NaN                NaN
# max           NaN       NaN                NaN                NaN
#
#            longitude      latitude   other_theft         arson   assault_gbh  \
# count   16965.000000  16965.000000  17265.000000  17265.000000  17265.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean       26.780270    -28.902783    281.022821      4.204807    154.610194
# std         3.839633      3.201970    441.488851      5.842701    172.151418
# min        16.492180    -34.800590      0.000000      0.000000      0.000000
# 25%        25.305790    -31.621870     34.000000      0.000000     38.000000
# 50%        27.900260    -28.698080    112.000000      2.000000     95.000000
# 75%        29.702660    -26.196550    339.000000      6.000000    210.000000
# max        32.743480    -22.343310   6803.000000     59.000000   1658.000000
#
#         attempted_murder  attempted_sexoff  bank_robbery  burglary_nonres  \
# count       17265.000000      17265.000000  17265.000000     17265.000000
# unique               NaN               NaN           NaN              NaN
# top                  NaN               NaN           NaN              NaN
# freq                 NaN               NaN           NaN              NaN
# mean           15.765943          2.344570      0.019288        60.807935
# std            25.868634          3.310832      0.184014        80.312592
# min             0.000000         -1.000000      0.000000         0.000000
# 25%             2.000000          0.000000      0.000000        11.000000
# 50%             6.000000          1.000000      0.000000        34.000000
# 75%            19.000000          3.000000      0.000000        79.000000
# max           399.000000         45.000000      9.000000       918.000000
#
#         burglary_res    carjacking  commercial_crime  common_assault  \
# count   17265.000000  17265.000000      17265.000000    17265.000000
# unique           NaN           NaN               NaN             NaN
# top              NaN           NaN               NaN             NaN
# freq             NaN           NaN               NaN             NaN
# mean      195.823458     12.877150         71.601564      147.810715
# std       240.553229     30.249276        155.887962      209.809279
# min         0.000000      0.000000          0.000000        0.000000
# 25%        33.000000      0.000000          3.000000       23.000000
# 50%       105.000000      1.000000         14.000000       70.000000
# 75%       267.000000      9.000000         70.000000      187.000000
# max      2345.000000    554.000000       2870.000000     2810.000000
#
#         common_robbery  contact_sexoff           dui    drug_crime  \
# count     17265.000000    17265.000000  17265.000000  17265.000000
# unique             NaN             NaN           NaN           NaN
# top                NaN             NaN           NaN           NaN
# freq               NaN             NaN           NaN           NaN
# mean         44.470837        7.326267     57.577353    175.447727
# std          88.920979        5.875825    110.127136    353.702502
# min           0.000000        1.000000      0.000000      0.000000
# 25%           3.000000        6.000000      3.000000     15.000000
# 50%          14.000000        6.000000     16.000000     58.000000
# 75%          49.000000        7.000000     62.000000    179.000000
# max        1681.000000       93.000000   2687.000000   6571.000000
#
#         illegal_firearms    kidnapping  malicious_damage        murder  \
# count       17265.000000  17265.000000      17265.000000  17265.000000
# unique               NaN           NaN               NaN           NaN
# top                  NaN           NaN               NaN           NaN
# freq                 NaN           NaN               NaN           NaN
# mean           12.898407     12.120127        101.317000     16.650796
# std            21.982118     12.476593        136.613499     26.130766
# min             0.000000      1.000000          0.000000      0.000000
# 25%             1.000000      1.000000         16.000000      2.000000
# 50%             4.000000     13.000000         48.000000      7.000000
# 75%            15.000000     16.000000        131.000000     20.000000
# max           275.000000    128.000000       1647.000000    349.000000
#
#                 rape  robbery_nonres   robbery_res  cash_transit_robbery  \
# count   17265.000000    17265.000000  17265.000000          17265.000000
# unique           NaN             NaN           NaN                   NaN
# top              NaN             NaN           NaN                   NaN
# freq             NaN             NaN           NaN                   NaN
# mean       37.554474       15.642572     17.406777              0.170634
# std        43.858709       23.381612     31.663089              0.598854
# min         0.000000        0.000000      0.000000              0.000000
# 25%         8.000000        1.000000      1.000000              0.000000
# 50%        22.000000        6.000000      5.000000              0.000000
# 75%        51.000000       21.000000     19.000000              0.000000
# max       446.000000      287.000000    484.000000             21.000000
#
#         aggr_robbery  sexual_assault  sexual_offences  police_detected_sexoff  \
# count   17265.000000    17265.000000     17265.000000            17265.000000
# unique           NaN             NaN              NaN                     NaN
# top              NaN             NaN              NaN                     NaN
# freq             NaN             NaN              NaN                     NaN
# mean      108.197567        5.993455        48.499855                4.366348
# std       182.975461        8.173655        56.574735               34.477296
# min         0.000000       -1.000000         0.000000                0.000000
# 25%         6.000000        1.000000        11.000000                0.000000
# 50%        29.000000        3.000000        30.000000                0.000000
# 75%       128.000000        8.000000        66.000000                0.000000
# max      2187.000000      161.000000      1371.000000             1084.000000
#
#          shoplifting   stock_theft  vehicle_theft  theft_from_vehicle  \
# count   17265.000000  17265.000000   17265.000000        17265.000000
# unique           NaN           NaN            NaN                 NaN
# top              NaN           NaN            NaN                 NaN
# freq             NaN           NaN            NaN                 NaN
# mean       57.158529     23.389053      46.262323          104.482827
# std       132.531411     32.246618     104.979312          223.672552
# min         0.000000      0.000000       0.000000           -1.000000
# 25%         0.000000      2.000000       1.000000            4.000000
# 50%         4.000000     12.000000       6.000000           21.000000
# 75%        52.000000     32.000000      35.000000           98.000000
# max      2570.000000    406.000000    1366.000000         3956.000000
#
#         truck_hijacking
# count      17265.000000
# unique              NaN
# top                 NaN
# freq                NaN
# mean           1.091978
# std            3.661221
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%            1.000000
# max           99.000000

# %%
# 3. Missing values
print("\n=== Missing Values ===")
missing = df_raw.isnull().sum()
missing_pct = (missing / len(df_raw)) * 100
missing_df = pd.DataFrame({'missing_count':missing, 'missing_pct':missing_pct})
print(missing_df[missing_df['missing_count']>0].sort_values('missing_pct', ascending=False))
# Out:
# === Missing Values ===
#            missing_count  missing_pct
# latitude             300     1.737619
# longitude            300     1.737619
# dc_mn                285     1.650738
# loc_mn               285     1.650738

# %%
# 4. Duplicates
print("\n===Duplicates===")
print(f'Duplicate rows: {df_raw.duplicated().sum()}')
# Out:
# ===Duplicates===
# Duplicate rows: 0

# %%
# 5. Unique value counts per column
print("\n===Unique Values===")
for col in df_raw.columns:
    print(f"{col}: {df_raw[col].nunique()} unique values")
# Out:
# ===Unique Values===
# year: 15 unique values
# station: 1151 unique values
# loc_mn: 210 unique values
# dc_mn: 52 unique values
# longitude: 1130 unique values
# latitude: 1131 unique values
# other_theft: 1729 unique values
# arson: 56 unique values
# assault_gbh: 889 unique values
# attempted_murder: 211 unique values
# attempted_sexoff: 33 unique values
# bank_robbery: 7 unique values
# burglary_nonres: 523 unique values
# burglary_res: 1148 unique values
# carjacking: 234 unique values
# commercial_crime: 810 unique values
# common_assault: 1020 unique values
# common_robbery: 498 unique values
# contact_sexoff: 93 unique values
# dui: 627 unique values
# drug_crime: 1309 unique values
# illegal_firearms: 183 unique values
# kidnapping: 128 unique values
# malicious_damage: 730 unique values
# murder: 221 unique values
# rape: 296 unique values
# robbery_nonres: 177 unique values
# robbery_res: 239 unique values
# cash_transit_robbery: 14 unique values
# aggr_robbery: 930 unique values
# sexual_assault: 82 unique values
# sexual_offences: 355 unique values
# police_detected_sexoff: 218 unique values
# shoplifting: 696 unique values
# stock_theft: 236 unique values
# vehicle_theft: 634 unique values
# theft_from_vehicle: 1025 unique values
# truck_hijacking: 53 unique values

# %% [markdown]
# 3. *Data Cleaning & Preprocessing*

# %%
# make a copy to work on
df_clean = df_raw.copy()

# %%
# 1.Handle missing values
# For numeric columns, fill with median or mean, for categories, fill with mode
num_cols = df_clean.select_dtypes(include=np.number).columns
cat_cols = df_clean.select_dtypes(include='object').columns

for col in num_cols:
    df_clean[col].fillna(df_clean[col].median(), inplace=True)
    

for col in cat_cols:
    df_clean[col].fillna(df_clean[col].mode()[0]if not df_clean[col].mode().empty else "unknown", inplace=True)
                         
# 2. Remove duplicates if any
df_clean.drop_duplicates(inplace=True)                      

# 3. Standardize categorical columns (lowercase, trim)
for col in cat_cols:
    if df_clean[col].dtype == 'object':
       df_clean[col] = df_clean[col].str.lower().str.strip()

# %%
df_clean.to_csv('../data/cleaned/saps_crime_cleaned.csv', index=False)
print("cleaned dataset saved.")
# Out:
# cleaned dataset saved.

# %%
crime_mapping = {
    # Contact Crimes
    'murder': 'contact_crime',
    'attempted_murder': 'contact_crime',
    'assault_gbh': 'contact_crime',
    'common_assault': 'contact_crime',
    'rape': 'contact_crime',
    'sexual_assault': 'contact_crime',

    # Contact-Related
    'arson': 'contact_related',
    'malicious_damage': 'contact_related',

    # Property Crimes
    'burglary_res': 'property_crime',
    'burglary_nonres': 'property_crime',
    'vehicle_theft': 'property_crime',
    'theft_from_vehicle': 'property_crime',
    'shoplifting': 'property_crime',
    'stock_theft': 'property_crime',
    'other_theft': 'property_crime',

    # Robbery
    'common_robbery': 'robbery',
    'aggr_robbery': 'robbery',
    'carjacking': 'robbery',
    'truck_hijacking': 'robbery',
    'robbery_res': 'robbery',
    'robbery_nonres': 'robbery',
    'cash_transit_robbery': 'robbery',
    'bank_robbery': 'robbery',

    # Crime Detected
    'drug_crime': 'crime_detected',
    'dui': 'crime_detected',
    'illegal_firearms': 'crime_detected',

    # Other Serious
    'kidnapping': 'other_serious',
    'commercial_crime': 'other_serious',

    # Sexual Offences
    'contact_sexoff': 'sexual_offences',
    'sexual_offences': 'sexual_offences',
    'attempted_sexoff': 'sexual_offences',
    'police_detected_sexoff': 'sexual_offences'
}

# Create grouped dataframe
df_grouped = df_clean.copy()

# Create new grouped columns
for group in set(crime_mapping.values()):
    cols = [col for col in crime_mapping if col in df_grouped.columns and crime_mapping[col] == group]
    df_grouped[group] = df_grouped[cols].sum(axis=1)

# %%
df_grouped.head()
# Out:
#         year   station                loc_mn                 dc_mn  longitude  \
# 0  2008/2009  yeoville  city of johannesburg  city of johannesburg   28.06281
# 1  2009/2010  yeoville  city of johannesburg  city of johannesburg   28.06281
# 2  2010/2011  yeoville  city of johannesburg  city of johannesburg   28.06281
# 3  2011/2012  yeoville  city of johannesburg  city of johannesburg   28.06281
# 4  2012/2013  yeoville  city of johannesburg  city of johannesburg   28.06281
#
#    latitude  other_theft  arson  assault_gbh  attempted_murder  \
# 0  -26.1829          491      3          570                25
# 1  -26.1829          452      5          625                 9
# 2  -26.1829          525      1          586                15
# 3  -26.1829          559      2          591                18
# 4  -26.1829          562      0          556                29
#
#    attempted_sexoff  bank_robbery  burglary_nonres  burglary_res  carjacking  \
# 0                 3             0              104           226          25
# 1                 3             0               86           180          35
# 2                 5             0               83           231          23
# 3                 5             0               92           199          54
# 4                 5             0               73           210          48
#
#    commercial_crime  common_assault  common_robbery  contact_sexoff  dui  \
# 0               161             443             132               1  213
# 1               154             473             127               2  264
# 2               247             469             113               3  228
# 3               197             437             103               4  340
# 4               129             441             134               5  351
#
#    drug_crime  illegal_firearms  kidnapping  malicious_damage  murder  rape  \
# 0         113                34           1               236      24    58
# 1         283                22           1               252      14    55
# 2         108                10           1               208      21    60
# 3         161                18           1               210      10    42
# 4         155                28           1               262      17    71
#
#    robbery_nonres  robbery_res  cash_transit_robbery  aggr_robbery  \
# 0              34           42                     1           293
# 1              27           57                     1           276
# 2              36           27                     0           238
# 3              54           46                     0           328
# 4              51           56                     1           355
#
#    sexual_assault  sexual_offences  police_detected_sexoff  shoplifting  \
# 0               7              123                       0          218
# 1              13              120                       0          185
# 2              23              109                       0          164
# 3               3               62                       1          111
# 4              17              109                       3          133
#
#    stock_theft  vehicle_theft  theft_from_vehicle  truck_hijacking  \
# 0            0            143                 272                0
# 1            0            124                 300                0
# 2            0             96                 256                0
# 3            0            104                 243                0
# 4            0            136                 380                0
#
#    contact_related  robbery  contact_crime  property_crime  crime_detected  \
# 0              239      527           1127            1454             360
# 1              257      523           1189            1327             569
# 2              209      437           1174            1355             346
# 3              212      585           1101            1308             519
# 4              262      645           1131            1494             534
#
#    other_serious
# 0            162
# 1            155
# 2            248
# 3            198
# 4            130

# %%
df_grouped.to_csv('../data/cleaned/saps_crime_cleaned_grouped.csv', index=False)
print("Grouped dataset saved.")
# Out:
# Grouped dataset saved.

# %% [markdown]
# 4. *Exploratory Data Analysis (EDA)*

# %% [markdown]
# - Visualize Trends

# %%
# Load cleaned grouped dataset
df = pd.read_csv('../data/cleaned/saps_crime_cleaned_grouped.csv')
df.head()
# Out:
#         year   station                loc_mn                 dc_mn  longitude  \
# 0  2008/2009  yeoville  city of johannesburg  city of johannesburg   28.06281
# 1  2009/2010  yeoville  city of johannesburg  city of johannesburg   28.06281
# 2  2010/2011  yeoville  city of johannesburg  city of johannesburg   28.06281
# 3  2011/2012  yeoville  city of johannesburg  city of johannesburg   28.06281
# 4  2012/2013  yeoville  city of johannesburg  city of johannesburg   28.06281
#
#    latitude  other_theft  arson  assault_gbh  attempted_murder  \
# 0  -26.1829          491      3          570                25
# 1  -26.1829          452      5          625                 9
# 2  -26.1829          525      1          586                15
# 3  -26.1829          559      2          591                18
# 4  -26.1829          562      0          556                29
#
#    attempted_sexoff  bank_robbery  burglary_nonres  burglary_res  carjacking  \
# 0                 3             0              104           226          25
# 1                 3             0               86           180          35
# 2                 5             0               83           231          23
# 3                 5             0               92           199          54
# 4                 5             0               73           210          48
#
#    commercial_crime  common_assault  common_robbery  contact_sexoff  dui  \
# 0               161             443             132               1  213
# 1               154             473             127               2  264
# 2               247             469             113               3  228
# 3               197             437             103               4  340
# 4               129             441             134               5  351
#
#    drug_crime  illegal_firearms  kidnapping  malicious_damage  murder  rape  \
# 0         113                34           1               236      24    58
# 1         283                22           1               252      14    55
# 2         108                10           1               208      21    60
# 3         161                18           1               210      10    42
# 4         155                28           1               262      17    71
#
#    robbery_nonres  robbery_res  cash_transit_robbery  aggr_robbery  \
# 0              34           42                     1           293
# 1              27           57                     1           276
# 2              36           27                     0           238
# 3              54           46                     0           328
# 4              51           56                     1           355
#
#    sexual_assault  sexual_offences  police_detected_sexoff  shoplifting  \
# 0               7              123                       0          218
# 1              13              120                       0          185
# 2              23              109                       0          164
# 3               3               62                       1          111
# 4              17              109                       3          133
#
#    stock_theft  vehicle_theft  theft_from_vehicle  truck_hijacking  \
# 0            0            143                 272                0
# 1            0            124                 300                0
# 2            0             96                 256                0
# 3            0            104                 243                0
# 4            0            136                 380                0
#
#    contact_related  robbery  contact_crime  property_crime  crime_detected  \
# 0              239      527           1127            1454             360
# 1              257      523           1189            1327             569
# 2              209      437           1174            1355             346
# 3              212      585           1101            1308             519
# 4              262      645           1131            1494             534
#
#    other_serious
# 0            162
# 1            155
# 2            248
# 3            198
# 4            130

# %%
# 1. Total crimes over time
plt.figure(figsize=(12,6))
sns.lineplot(data=df, x='year', y=['contact_related', 'robbery', 'contact_crime', 'property_crime', 'crime_detected', 'other_serious'], estimator='sum', errorbar=None)
plt.title('Total Crimes per Year (All Categories)')
plt.ylabel('Total Cases')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 3
#       1 # 1. Total crimes over time
#       2 plt.figure(figsize=(12,6))
# ----> 3 sns.lineplot(data=df, x='year', y=['contact_related', 'robbery', 'contact_crime', 'property_crime', 'crime_detected', 'other_serious'], estimator='sum', errorbar=None)
#       4 plt.title('Total Crimes per Year (All Categories)')
#       5 plt.ylabel('Total Cases')
#
# File ~\.pyenv\pyenv-win\versions\3.11.0\Lib\site-packages\seaborn\relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)
#     481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
#     488             x=x, y=y, hue=hue, size=size, style=style, units=units, weight=weights
#     489         ),
#     490         estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     491         sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     492         legend=legend,
#     493     )
#     495     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     496     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~\.pyenv\pyenv-win\versions\3.11.0\Lib\site-packages\seaborn\relational.py:216, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     202 def __init__(
#     203     self, *,
#     204     data=None, variables={},
#    (...)
#     210     # the kind of plot to draw, but for the time being we need to set
#     211     # this information so the SizeMapping can use it
#     212     self._default_size_range = (
#     213         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     214     )
# --> 216     super().__init__(data=data, variables=variables)
#     218     self.estimator = estimator
#     219     self.errorbar = errorbar
#
# File ~\.pyenv\pyenv-win\versions\3.11.0\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File ~\.pyenv\pyenv-win\versions\3.11.0\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File ~\.pyenv\pyenv-win\versions\3.11.0\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File ~\.pyenv\pyenv-win\versions\3.11.0\Lib\site-packages\seaborn\_core\data.py:251, in PlotData._assign_variables(self, data, variables)
#     245         val_cls = val.__class__.__name__
#     246         err = (
#     247             f"Length of {val_cls} vectors must match length of `data`"
#     248             f" when both are used, but `data` has length {len(data)}"
#     249             f" and the vector passed to `{key}` has length {len(val)}."
#     250         )
# --> 251         raise ValueError(err)
#     253 plot_data[key] = val
#     255 # Try to infer the original name using pandas-like metadata
#
# ValueError: Length of list vectors must match length of `data` when both are used, but `data` has length 17265 and the vector passed to `y` has length 6.
